# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
# CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
# PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
# PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
# TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
# LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_big' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    # url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    # wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} #&& tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.8.10: c:\Users\johannes.erfurt\python_projects\TFODCourse\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2024-10-27 16:01:00.963926: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE SSE2 SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W1027 16:01:00.980022 16232 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# c:\Users\johannes.erfurt\python_projects\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W1027 16:01:01.176908 16232 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.37s
# I1027 16:01:01.330012 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.37s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.62s
# I1027 16:01:01.952108 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.62s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.16s
# I1027 16:01:02.115095 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.16s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# I1027 16:01:02.330767 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.18s
# I1027 16:01:03.513334 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.18s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1027 16:01:03.515333 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# I1027 16:01:03.529332 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I1027 16:01:03.539318 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I1027 16:01:03.549331 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# I1027 16:01:03.606334 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# I1027 16:01:03.660321 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# I1027 16:01:03.716322 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# I1027 16:01:03.773595 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# I1027 16:01:03.827403 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I1027 16:01:03.843398 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1027 16:01:03.943385 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1027 16:01:03.943385 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I1027 16:01:03.944384 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I1027 16:01:03.948490 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:03.965384 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:03.965384 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:04.007384 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:04.007384 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:04.114384 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:04.114384 16232 efficientnet_model.py:143] round_filter input=40 output=40
# I1027 16:01:04.296195 16232 efficientnet_model.py:143] round_filter input=40 output=40
# I1027 16:01:04.296195 16232 efficientnet_model.py:143] round_filter input=80 output=80
# I1027 16:01:04.457767 16232 efficientnet_model.py:143] round_filter input=80 output=80
# I1027 16:01:04.457767 16232 efficientnet_model.py:143] round_filter input=112 output=112
# I1027 16:01:04.623768 16232 efficientnet_model.py:143] round_filter input=112 output=112
# I1027 16:01:04.623768 16232 efficientnet_model.py:143] round_filter input=192 output=192
# I1027 16:01:04.834767 16232 efficientnet_model.py:143] round_filter input=192 output=192
# I1027 16:01:04.834767 16232 efficientnet_model.py:143] round_filter input=320 output=320
# I1027 16:01:04.890767 16232 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1027 16:01:04.924767 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:04.953768 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1027 16:01:04.953768 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I1027 16:01:04.953768 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I1027 16:01:04.954817 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:04.963877 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:04.963877 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:05.038769 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:05.038769 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:05.171770 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:05.171770 16232 efficientnet_model.py:143] round_filter input=40 output=40
# I1027 16:01:05.308781 16232 efficientnet_model.py:143] round_filter input=40 output=40
# I1027 16:01:05.308781 16232 efficientnet_model.py:143] round_filter input=80 output=80
# I1027 16:01:05.496320 16232 efficientnet_model.py:143] round_filter input=80 output=80
# I1027 16:01:05.496320 16232 efficientnet_model.py:143] round_filter input=112 output=112
# I1027 16:01:05.687786 16232 efficientnet_model.py:143] round_filter input=112 output=112
# I1027 16:01:05.687786 16232 efficientnet_model.py:143] round_filter input=192 output=192
# I1027 16:01:05.941169 16232 efficientnet_model.py:143] round_filter input=192 output=192
# I1027 16:01:05.941169 16232 efficientnet_model.py:143] round_filter input=320 output=320
# I1027 16:01:06.071158 16232 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1027 16:01:06.100170 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:06.136159 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1027 16:01:06.136159 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 112
# I1027 16:01:06.136159 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 5
# I1027 16:01:06.137159 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:06.146159 16232 efficientnet_model.py:143] round_filter input=32 output=32
# I1027 16:01:06.147159 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:06.220162 16232 efficientnet_model.py:143] round_filter input=16 output=16
# I1027 16:01:06.220162 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:06.364262 16232 efficientnet_model.py:143] round_filter input=24 output=24
# I1027 16:01:06.364262 16232 efficientnet_model.py:143] round_filter input=40 output=48
# I1027 16:01:06.516270 16232 efficientnet_model.py:143] round_filter input=40 output=48
# I1027 16:01:06.516270 16232 efficientnet_model.py:143] round_filter input=80 output=88
# I1027 16:01:06.721820 16232 efficientnet_model.py:143] round_filter input=80 output=88
# I1027 16:01:06.721820 16232 efficientnet_model.py:143] round_filter input=112 output=120
# I1027 16:01:06.925821 16232 efficientnet_model.py:143] round_filter input=112 output=120
# I1027 16:01:06.925821 16232 efficientnet_model.py:143] round_filter input=192 output=208
# I1027 16:01:07.206819 16232 efficientnet_model.py:143] round_filter input=192 output=208
# I1027 16:01:07.207843 16232 efficientnet_model.py:143] round_filter input=320 output=352
# I1027 16:01:07.357821 16232 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1027 16:01:07.392821 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:07.518822 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1027 16:01:07.518822 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 160
# I1027 16:01:07.518822 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 6
# I1027 16:01:07.519823 16232 efficientnet_model.py:143] round_filter input=32 output=40
# I1027 16:01:07.529822 16232 efficientnet_model.py:143] round_filter input=32 output=40
# I1027 16:01:07.529822 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:07.610823 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:07.610823 16232 efficientnet_model.py:143] round_filter input=24 output=32
# I1027 16:01:07.750821 16232 efficientnet_model.py:143] round_filter input=24 output=32
# I1027 16:01:07.750821 16232 efficientnet_model.py:143] round_filter input=40 output=48
# I1027 16:01:07.888905 16232 efficientnet_model.py:143] round_filter input=40 output=48
# I1027 16:01:07.888905 16232 efficientnet_model.py:143] round_filter input=80 output=96
# I1027 16:01:08.133565 16232 efficientnet_model.py:143] round_filter input=80 output=96
# I1027 16:01:08.133565 16232 efficientnet_model.py:143] round_filter input=112 output=136
# I1027 16:01:08.389387 16232 efficientnet_model.py:143] round_filter input=112 output=136
# I1027 16:01:08.389387 16232 efficientnet_model.py:143] round_filter input=192 output=232
# I1027 16:01:08.719475 16232 efficientnet_model.py:143] round_filter input=192 output=232
# I1027 16:01:08.719475 16232 efficientnet_model.py:143] round_filter input=320 output=384
# I1027 16:01:08.852475 16232 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1027 16:01:08.887475 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:08.923476 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1027 16:01:08.923476 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 224
# I1027 16:01:08.923476 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1027 16:01:08.924475 16232 efficientnet_model.py:143] round_filter input=32 output=48
# I1027 16:01:08.934477 16232 efficientnet_model.py:143] round_filter input=32 output=48
# I1027 16:01:08.934477 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:09.008476 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:09.008476 16232 efficientnet_model.py:143] round_filter input=24 output=32
# I1027 16:01:09.186475 16232 efficientnet_model.py:143] round_filter input=24 output=32
# I1027 16:01:09.186475 16232 efficientnet_model.py:143] round_filter input=40 output=56
# I1027 16:01:09.383995 16232 efficientnet_model.py:143] round_filter input=40 output=56
# I1027 16:01:09.383995 16232 efficientnet_model.py:143] round_filter input=80 output=112
# I1027 16:01:09.665744 16232 efficientnet_model.py:143] round_filter input=80 output=112
# I1027 16:01:09.665744 16232 efficientnet_model.py:143] round_filter input=112 output=160
# I1027 16:01:09.969832 16232 efficientnet_model.py:143] round_filter input=112 output=160
# I1027 16:01:09.969832 16232 efficientnet_model.py:143] round_filter input=192 output=272
# I1027 16:01:10.423833 16232 efficientnet_model.py:143] round_filter input=192 output=272
# I1027 16:01:10.423833 16232 efficientnet_model.py:143] round_filter input=320 output=448
# I1027 16:01:10.561833 16232 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1027 16:01:10.596859 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:10.637797 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1027 16:01:10.637797 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I1027 16:01:10.637797 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1027 16:01:10.638833 16232 efficientnet_model.py:143] round_filter input=32 output=48
# I1027 16:01:10.647812 16232 efficientnet_model.py:143] round_filter input=32 output=48
# I1027 16:01:10.647812 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:10.750844 16232 efficientnet_model.py:143] round_filter input=16 output=24
# I1027 16:01:10.750844 16232 efficientnet_model.py:143] round_filter input=24 output=40
# I1027 16:01:10.972637 16232 efficientnet_model.py:143] round_filter input=24 output=40
# I1027 16:01:10.972637 16232 efficientnet_model.py:143] round_filter input=40 output=64
# I1027 16:01:11.345641 16232 efficientnet_model.py:143] round_filter input=40 output=64
# I1027 16:01:11.345641 16232 efficientnet_model.py:143] round_filter input=80 output=128
# I1027 16:01:11.686328 16232 efficientnet_model.py:143] round_filter input=80 output=128
# I1027 16:01:11.686328 16232 efficientnet_model.py:143] round_filter input=112 output=176
# I1027 16:01:12.044339 16232 efficientnet_model.py:143] round_filter input=112 output=176
# I1027 16:01:12.044339 16232 efficientnet_model.py:143] round_filter input=192 output=304
# I1027 16:01:12.566278 16232 efficientnet_model.py:143] round_filter input=192 output=304
# I1027 16:01:12.566278 16232 efficientnet_model.py:143] round_filter input=320 output=512
# I1027 16:01:12.786852 16232 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1027 16:01:12.824874 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:12.871845 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1027 16:01:12.871845 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1027 16:01:12.871845 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1027 16:01:12.872850 16232 efficientnet_model.py:143] round_filter input=32 output=56
# I1027 16:01:12.882851 16232 efficientnet_model.py:143] round_filter input=32 output=56
# I1027 16:01:12.882851 16232 efficientnet_model.py:143] round_filter input=16 output=32
# I1027 16:01:12.989839 16232 efficientnet_model.py:143] round_filter input=16 output=32
# I1027 16:01:12.990837 16232 efficientnet_model.py:143] round_filter input=24 output=40
# I1027 16:01:13.262683 16232 efficientnet_model.py:143] round_filter input=24 output=40
# I1027 16:01:13.262683 16232 efficientnet_model.py:143] round_filter input=40 output=72
# I1027 16:01:13.556417 16232 efficientnet_model.py:143] round_filter input=40 output=72
# I1027 16:01:13.556417 16232 efficientnet_model.py:143] round_filter input=80 output=144
# I1027 16:01:13.955429 16232 efficientnet_model.py:143] round_filter input=80 output=144
# I1027 16:01:13.955429 16232 efficientnet_model.py:143] round_filter input=112 output=200
# I1027 16:01:14.383234 16232 efficientnet_model.py:143] round_filter input=112 output=200
# I1027 16:01:14.383234 16232 efficientnet_model.py:143] round_filter input=192 output=344
# I1027 16:01:15.072235 16232 efficientnet_model.py:143] round_filter input=192 output=344
# I1027 16:01:15.072235 16232 efficientnet_model.py:143] round_filter input=320 output=576
# I1027 16:01:15.322233 16232 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1027 16:01:15.486233 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1027 16:01:15.539915 16232 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1027 16:01:15.539915 16232 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1027 16:01:15.539915 16232 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1027 16:01:15.540914 16232 efficientnet_model.py:143] round_filter input=32 output=64
# I1027 16:01:15.551915 16232 efficientnet_model.py:143] round_filter input=32 output=64
# I1027 16:01:15.551915 16232 efficientnet_model.py:143] round_filter input=16 output=32
# I1027 16:01:15.691917 16232 efficientnet_model.py:143] round_filter input=16 output=32
# I1027 16:01:15.692917 16232 efficientnet_model.py:143] round_filter input=24 output=48
# I1027 16:01:16.012084 16232 efficientnet_model.py:143] round_filter input=24 output=48
# I1027 16:01:16.012084 16232 efficientnet_model.py:143] round_filter input=40 output=80
# I1027 16:01:16.336083 16232 efficientnet_model.py:143] round_filter input=40 output=80
# I1027 16:01:16.336083 16232 efficientnet_model.py:143] round_filter input=80 output=160
# I1027 16:01:16.833043 16232 efficientnet_model.py:143] round_filter input=80 output=160
# I1027 16:01:16.833043 16232 efficientnet_model.py:143] round_filter input=112 output=224
# I1027 16:01:17.373873 16232 efficientnet_model.py:143] round_filter input=112 output=224
# I1027 16:01:17.373873 16232 efficientnet_model.py:143] round_filter input=192 output=384
# I1027 16:01:18.210874 16232 efficientnet_model.py:143] round_filter input=192 output=384
# I1027 16:01:18.210874 16232 efficientnet_model.py:143] round_filter input=320 output=640
# I1027 16:01:18.564550 16232 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1027 16:01:18.609859 16232 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.83s
# I1027 16:01:18.671868 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.83s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1027 16:01:18.682857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1027 16:01:18.683857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1027 16:01:18.684857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1027 16:01:18.684857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1027 16:01:18.685857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1027 16:01:18.685857 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1027 16:01:18.686858 16232 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 17.725s
#
# OK (skipped=1)

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#         1 Datei(en) verschoben.
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}, {'name':'Excellent', 'id':3}, {'name':'FuckYou', 'id':4}]
# labels = [{'name':'Johannes', 'id':1}, {'name':'Tatjana', 'id':2}, {'name':'Leonie', 'id':3}, {'name':'Elias', 'id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}
# Out:
# Tensorflow/workspace/images/train/
# Tensorflow/workspace/images/train/fuckyou.8e481a7c-911f-11ef-87a1-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.8e481a7c-911f-11ef-87a1-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.8f7ebc79-911f-11ef-b217-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.8f7ebc79-911f-11ef-b217-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.90b396b6-911f-11ef-a44d-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.90b396b6-911f-11ef-a44d-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.91e6e72c-911f-11ef-8199-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.91e6e72c-911f-11ef-8199-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.931ac98c-911f-11ef-9860-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.931ac98c-911f-11ef-9860-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9451993f-911f-11ef-bbf9-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9451993f-911f-11ef-bbf9-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9587174a-911f-11ef-a2e0-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9587174a-911f-11ef-a2e0-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.96bdd6f8-911f-11ef-9e93-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.96bdd6f8-911f-11ef-9e93-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.97f170ad-911f-11ef-965c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.97f170ad-911f-11ef-965c-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.99258ce0-911f-11ef-adb8-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.99258ce0-911f-11ef-adb8-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9a59aea7-911f-11ef-9c85-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9a59aea7-911f-11ef-9c85-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9b8f6a38-911f-11ef-b3df-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9b8f6a38-911f-11ef-b3df-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9cc395a7-911f-11ef-896e-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9cc395a7-911f-11ef-896e-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9df86359-911f-11ef-8759-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9df86359-911f-11ef-8759-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.9f2e65f2-911f-11ef-ae95-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.9f2e65f2-911f-11ef-ae95-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a0633acf-911f-11ef-96d4-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a0633acf-911f-11ef-96d4-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a1986a65-911f-11ef-845c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a1986a65-911f-11ef-845c-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a2ceea16-911f-11ef-8073-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a2ceea16-911f-11ef-8073-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a4024f4b-911f-11ef-9152-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a4024f4b-911f-11ef-9152-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a66f1a28-911f-11ef-89a7-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a66f1a28-911f-11ef-89a7-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a7a46c8c-911f-11ef-ae78-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a7a46c8c-911f-11ef-ae78-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.a8db71a0-911f-11ef-9c73-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.a8db71a0-911f-11ef-9c73-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.aa10319d-911f-11ef-9707-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.aa10319d-911f-11ef-9707-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.ab442b3a-911f-11ef-800e-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.ab442b3a-911f-11ef-800e-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.cdd14624-911e-11ef-8a73-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.cdd14624-911e-11ef-8a73-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.cf065f5f-911e-11ef-be7c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.cf065f5f-911e-11ef-be7c-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d03b121b-911e-11ef-b3f5-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d03b121b-911e-11ef-b3f5-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d16e10bb-911e-11ef-b0a2-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d16e10bb-911e-11ef-b0a2-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d2a2f790-911e-11ef-b4d3-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d2a2f790-911e-11ef-b4d3-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d3d65c0b-911e-11ef-a81c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d3d65c0b-911e-11ef-a81c-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d50a40b2-911e-11ef-9878-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d50a40b2-911e-11ef-9878-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d63ffcf8-911e-11ef-b6a7-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d63ffcf8-911e-11ef-b6a7-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d773951c-911e-11ef-904b-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d773951c-911e-11ef-904b-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d8a8011d-911e-11ef-a2c1-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d8a8011d-911e-11ef-a2c1-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.d9db3a4e-911e-11ef-b9dd-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.d9db3a4e-911e-11ef-b9dd-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.db0ef463-911e-11ef-8b19-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.db0ef463-911e-11ef-8b19-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.dc439c8e-911e-11ef-978e-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.dc439c8e-911e-11ef-978e-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.dd7756dd-911e-11ef-a084-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.dd7756dd-911e-11ef-a084-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.deae67a2-911e-11ef-b1c9-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.deae67a2-911e-11ef-b1c9-d4d853125d26.xml
# Tensorflow/workspace/images/train/fuckyou.dfe0f968-911e-11ef-a588-d4d853125d26.jpg
# Tensorflow/workspace/images/train/fuckyou.dfe0f968-911e-11ef-a588-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.4a18ead1-911f-11ef-ab8c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.4a18ead1-911f-11ef-ab8c-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.4b4df69a-911f-11ef-9b4f-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.4b4df69a-911f-11ef-9b4f-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.4c80821b-911f-11ef-9b8b-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.4c80821b-911f-11ef-9b8b-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.4db48bde-911f-11ef-a8ad-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.4db48bde-911f-11ef-a8ad-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.4ee99747-911f-11ef-b379-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.4ee99747-911f-11ef-b379-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.501f8509-911f-11ef-98af-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.501f8509-911f-11ef-98af-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5289cad6-911f-11ef-8a52-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5289cad6-911f-11ef-8a52-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.53bee68a-911f-11ef-b99d-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.53bee68a-911f-11ef-b99d-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.54f2a3ce-911f-11ef-a798-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.54f2a3ce-911f-11ef-a798-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.575b14a7-911f-11ef-bf0c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.575b14a7-911f-11ef-bf0c-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.59c38fa5-911f-11ef-931a-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.59c38fa5-911f-11ef-931a-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5afa28ee-911f-11ef-8e83-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5afa28ee-911f-11ef-8e83-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5c2d9273-911f-11ef-b297-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5c2d9273-911f-11ef-b297-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5d64fcf7-911f-11ef-a008-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5d64fcf7-911f-11ef-a008-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5e992e5b-911f-11ef-a284-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5e992e5b-911f-11ef-a284-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.5fcdfa08-911f-11ef-a908-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.5fcdfa08-911f-11ef-a908-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.6236a85c-911f-11ef-aac2-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.6236a85c-911f-11ef-aac2-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.636d6ecd-911f-11ef-9894-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.636d6ecd-911f-11ef-9894-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.64a42134-911f-11ef-a713-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.64a42134-911f-11ef-a713-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.65d80c81-911f-11ef-b791-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.65d80c81-911f-11ef-b791-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.670bb3be-911f-11ef-a56a-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.670bb3be-911f-11ef-a56a-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.89bf484c-911e-11ef-8f52-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.89bf484c-911e-11ef-8f52-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.8af4e3f2-911e-11ef-8621-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.8af4e3f2-911e-11ef-8621-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.8c282fe0-911e-11ef-9355-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.8c282fe0-911e-11ef-9355-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.8d5d2077-911e-11ef-8d1c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.8d5d2077-911e-11ef-8d1c-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.8e92047d-911e-11ef-88c6-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.8e92047d-911e-11ef-88c6-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.8fc617db-911e-11ef-9e8b-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.8fc617db-911e-11ef-9e8b-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.90fb6124-911e-11ef-8894-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.90fb6124-911e-11ef-8894-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.922f6455-911e-11ef-ab68-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.922f6455-911e-11ef-ab68-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9364afa7-911e-11ef-8572-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9364afa7-911e-11ef-8572-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9499bf80-911e-11ef-ac5c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9499bf80-911e-11ef-ac5c-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.95ce20ee-911e-11ef-9f48-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.95ce20ee-911e-11ef-9f48-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9702b329-911e-11ef-a8ba-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9702b329-911e-11ef-a8ba-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9837c1ad-911e-11ef-b316-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9837c1ad-911e-11ef-b316-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.996c31b1-911e-11ef-8826-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.996c31b1-911e-11ef-8826-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9aa341d3-911e-11ef-a91c-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9aa341d3-911e-11ef-a91c-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9bd891ee-911e-11ef-aca2-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9bd891ee-911e-11ef-aca2-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9d0c07b1-911e-11ef-b2fb-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9d0c07b1-911e-11ef-b2fb-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9e410436-911e-11ef-88e7-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9e410436-911e-11ef-88e7-d4d853125d26.xml
# Tensorflow/workspace/images/train/thumbsdown.9f75189b-911e-11ef-a403-d4d853125d26.jpg
# Tensorflow/workspace/images/train/thumbsdown.9f75189b-911e-11ef-a403-d4d853125d26.xml
# Tensorflow/workspace/images/test/
# Tensorflow/workspace/images/test/fuckyou.e115cd8e-911e-11ef-bb84-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e115cd8e-911e-11ef-bb84-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e24cdbd5-911e-11ef-9e33-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e24cdbd5-911e-11ef-9e33-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e38438eb-911e-11ef-a823-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e38438eb-911e-11ef-a823-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e4b8c423-911e-11ef-af38-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e4b8c423-911e-11ef-af38-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e5ed2ace-911e-11ef-89f7-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e5ed2ace-911e-11ef-89f7-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e721ff38-911e-11ef-8622-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e721ff38-911e-11ef-8622-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e858e1cf-911e-11ef-b615-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e858e1cf-911e-11ef-b615-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.e98cb816-911e-11ef-8196-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.e98cb816-911e-11ef-8196-d4d853125d26.xml
# Tensorflow/workspace/images/test/fuckyou.eac2c0f1-911e-11ef-a87f-d4d853125d26.jpg
# Tensorflow/workspace/images/test/fuckyou.eac2c0f1-911e-11ef-a87f-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.51550007-911f-11ef-bdb3-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.51550007-911f-11ef-bdb3-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.56266642-911f-11ef-b3f0-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.56266642-911f-11ef-b3f0-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.58902911-911f-11ef-9ba5-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.58902911-911f-11ef-9ba5-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.61023578-911f-11ef-882c-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.61023578-911f-11ef-882c-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a0a83386-911e-11ef-b101-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a0a83386-911e-11ef-b101-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a1dd1c70-911e-11ef-9795-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a1dd1c70-911e-11ef-9795-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a310dfb5-911e-11ef-9956-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a310dfb5-911e-11ef-9956-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a44688d7-911e-11ef-aeac-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a44688d7-911e-11ef-aeac-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a57b2de8-911e-11ef-bf0b-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a57b2de8-911e-11ef-bf0b-d4d853125d26.xml
# Tensorflow/workspace/images/test/thumbsdown.a6af45b5-911e-11ef-bb87-d4d853125d26.jpg
# Tensorflow/workspace/images/test/thumbsdown.a6af45b5-911e-11ef-bb87-d4d853125d26.xml

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 Datei(en) kopiert.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_big --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_big\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-11')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'fuckyou.e115cd8e-911e-11ef-bb84-d4d853125d26.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))

detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_big\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_big --output_directory=Tensorflow\workspace\models\my_ssd_mobnet_big\export

# %%
# !{command}

# %%
# !pip install tf2onnx

import tensorflow as tf
import tf2onnx
import os

# Define the path to the frozen graph (.pb file)
frozen_graph_path = os.path.join(paths['OUTPUT_PATH'], 'saved_model', 'saved_model.pb')

# Define the path where you want to save the ONNX file
onnx_path = os.path.join(paths['OUTPUT_PATH'], 'model.onnx')

# Load the frozen graph
with tf.io.gfile.GFile(frozen_graph_path, "rb") as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())

# Import the graph into a new graph and session
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name="")

# Convert the model to ONNX
with tf.compat.v1.Session(graph=graph) as sess:
    input_names = [n.name for n in graph.as_graph_def().node if n.op == 'Placeholder']
    output_names = [n.name for n in graph.as_graph_def().node if n.op == 'Softmax']  # Adjust this based on your model's output node
    onnx_graph = tf2onnx.tfonnx.process_tf_graph(sess.graph, input_names=input_names, output_names=output_names)
    model_proto = onnx_graph.make_model("Converted from TensorFlow")

# Save the ONNX model
with open(onnx_path, "wb") as f:
    f.write(model_proto.SerializeToString())

print(f"Model has been converted to ONNX and saved at {onnx_path}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 4
#       1 # !pip install tf2onnx
#       3 import tensorflow as tf
# ----> 4 import tf2onnx
#       5 import os
#       7 # Define the path to the frozen graph (.pb file)
#
# File c:\Users\johannes.erfurt\python_projects\TFODCourse\tfod\lib\site-packages\tf2onnx\__init__.py:8
#       3 """tf2onnx package."""
#       5 __all__ = ["utils", "graph_matcher", "graph", "graph_builder",
#       6            "tfonnx", "shape_inference", "schemas", "tf_utils", "tf_loader", "convert"]
# ----> 8 import onnx
#       9 from .version import git_version, version as __version__
#      10 from . import verbose_logging as logging
#
# File c:\Users\johannes.erfurt\python_projects\TFODCourse\tfod\lib\site-packages\onnx\__init__.py:77
#      73 from typing import IO, Literal, Union
#      76 from onnx import serialization
# ---> 77 from onnx.onnx_cpp2py_export import ONNX_ML
#      78 from onnx.external_data_helper import (
#      79     load_external_data_for_model,
#      80     write_external_data_tensors,
#      81     convert_model_to_external_data,
#      82 )
#      83 from onnx.onnx_pb import (
#      84     AttributeProto,
#      85     EXPERIMENTAL,
#    (...)
#     111     Version,
#     112 )
#
# ImportError: DLL load failed while importing onnx_cpp2py_export: Eine DLL-Initialisierungsroutine ist fehlgeschlagen.

# %%
import onnx
print(onnx.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import onnx
#       2 print(onnx.__version__)
#
# File c:\Users\johannes.erfurt\python_projects\TFODCourse\tfod\lib\site-packages\onnx\__init__.py:77
#      73 from typing import IO, Literal, Union
#      76 from onnx import serialization
# ---> 77 from onnx.onnx_cpp2py_export import ONNX_ML
#      78 from onnx.external_data_helper import (
#      79     load_external_data_for_model,
#      80     write_external_data_tensors,
#      81     convert_model_to_external_data,
#      82 )
#      83 from onnx.onnx_pb import (
#      84     AttributeProto,
#      85     EXPERIMENTAL,
#    (...)
#     111     Version,
#     112 )
#
# ImportError: DLL load failed while importing onnx_cpp2py_export: Eine DLL-Initialisierungsroutine ist fehlgeschlagen.

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport

# %%
# !{command}
# Out:
# Der Befehl "tensorflowjs_converter" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
